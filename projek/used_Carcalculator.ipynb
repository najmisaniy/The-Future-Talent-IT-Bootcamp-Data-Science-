# %%
import pandas as pd  
import numpy as np

df_usedcar_data=pd.read_csv('train.csv')
df_usedcar_data.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# ...

# %%
df_usedcar_data.describe(include='all')
# Out:
#                   ID         Price   Levy Manufacturer  Model    Prod. year  \
# count   1.923700e+04  1.923700e+04  19237        19237  19237  19237.000000
# unique           NaN           NaN    559           65   1590           NaN
# top              NaN           NaN      -      HYUNDAI  Prius           NaN
# freq             NaN           NaN   5819         3769   1083           NaN
# mean    4.557654e+07  1.855593e+04    NaN          NaN    NaN   2010.912824
# std     9.365914e+05  1.905813e+05    NaN          NaN    NaN      5.668673
# min     2.074688e+07  1.000000e+00    NaN          NaN    NaN   1939.000000
# 25%     4.569837e+07  5.331000e+03    NaN          NaN    NaN   2009.000000
# 50%     4.577231e+07  1.317200e+04    NaN          NaN    NaN   2012.000000
# 75%     4.580204e+07  2.207500e+04    NaN          NaN    NaN   2015.000000
# max     4.581665e+07  2.630750e+07    NaN          NaN    NaN   2020.000000
#
# ...

# %%
df_usedcar_data['ID']=df_usedcar_data['ID'].astype('str')
df_usedcar_data['Prod. year']=df_usedcar_data['Prod. year'].astype('str')

df_usedcar_data.describe(include='all')
# Out:
#               ID         Price   Levy Manufacturer  Model Prod. year Category  \
# count      19237  1.923700e+04  19237        19237  19237      19237    19237
# unique     18924           NaN    559           65   1590         54       11
# top     45815365           NaN      -      HYUNDAI  Prius       2012    Sedan
# freq           8           NaN   5819         3769   1083       2155     8736
# mean         NaN  1.855593e+04    NaN          NaN    NaN        NaN      NaN
# std          NaN  1.905813e+05    NaN          NaN    NaN        NaN      NaN
# min          NaN  1.000000e+00    NaN          NaN    NaN        NaN      NaN
# 25%          NaN  5.331000e+03    NaN          NaN    NaN        NaN      NaN
# 50%          NaN  1.317200e+04    NaN          NaN    NaN        NaN      NaN
# 75%          NaN  2.207500e+04    NaN          NaN    NaN        NaN      NaN
# max          NaN  2.630750e+07    NaN          NaN    NaN        NaN      NaN
#
# ...

# %%
df_usedcar_data.dtypes
# Out:
# ID                   object
# Price                 int64
# Levy                 object
# Manufacturer         object
# Model                object
# Prod. year           object
# Category             object
# Leather interior     object
# Fuel type            object
# Engine volume        object
# Mileage              object
# Cylinders           float64
# Gear box type        object
# Drive wheels         object
# Doors                object
# Wheel                object
# Color                object
# Airbags               int64
# dtype: object

# %%
df_usedcar_data.describe()
# Out:
#                  ID         Price    Prod. year     Cylinders       Airbags
# count  1.923700e+04  1.923700e+04  19237.000000  19237.000000  19237.000000
# mean   4.557654e+07  1.855593e+04   2010.912824      4.582991      6.582627
# std    9.365914e+05  1.905813e+05      5.668673      1.199933      4.320168
# min    2.074688e+07  1.000000e+00   1939.000000      1.000000      0.000000
# 25%    4.569837e+07  5.331000e+03   2009.000000      4.000000      4.000000
# 50%    4.577231e+07  1.317200e+04   2012.000000      4.000000      6.000000
# 75%    4.580204e+07  2.207500e+04   2015.000000      4.000000     12.000000
# max    4.581665e+07  2.630750e+07   2020.000000     16.000000     16.000000

# %%
df_cleardup_ID=df_usedcar_data.drop_duplicates(subset='ID')
#df_cleardup_ID=pd.DataFrame(df_cleardup_ID)

# %%
df_usedcar_data.describe(include='all')
# Out:
#               ID         Price   Levy Manufacturer  Model Prod. year Category  \
# count      19237  1.923700e+04  19237        19237  19237      19237    19237
# unique     18924           NaN    559           65   1590         54       11
# top     45815365           NaN      -      HYUNDAI  Prius       2012    Sedan
# freq           8           NaN   5819         3769   1083       2155     8736
# mean         NaN  1.855593e+04    NaN          NaN    NaN        NaN      NaN
# std          NaN  1.905813e+05    NaN          NaN    NaN        NaN      NaN
# min          NaN  1.000000e+00    NaN          NaN    NaN        NaN      NaN
# 25%          NaN  5.331000e+03    NaN          NaN    NaN        NaN      NaN
# 50%          NaN  1.317200e+04    NaN          NaN    NaN        NaN      NaN
# 75%          NaN  2.207500e+04    NaN          NaN    NaN        NaN      NaN
# max          NaN  2.630750e+07    NaN          NaN    NaN        NaN      NaN
#
# ...

# %%
df_cleardup_ID.describe(include=('all'))
# Out:
#               ID         Price   Levy Manufacturer  Model Prod. year Category  \
# count      18924  1.892400e+04  18924        18924  18924      18924    18924
# unique     18924           NaN    559           65   1590         54       11
# top     45654403           NaN      -      HYUNDAI  Prius       2012    Sedan
# freq           1           NaN   5709         3729   1069       2131     8600
# mean         NaN  1.858744e+04    NaN          NaN    NaN        NaN      NaN
# std          NaN  1.921356e+05    NaN          NaN    NaN        NaN      NaN
# min          NaN  1.000000e+00    NaN          NaN    NaN        NaN      NaN
# 25%          NaN  5.331000e+03    NaN          NaN    NaN        NaN      NaN
# 50%          NaN  1.317200e+04    NaN          NaN    NaN        NaN      NaN
# 75%          NaN  2.206300e+04    NaN          NaN    NaN        NaN      NaN
# max          NaN  2.630750e+07    NaN          NaN    NaN        NaN      NaN
#
# ...

# %%
print(df_cleardup_ID.head())
# Out:
#          ID  Price  Levy Manufacturer    Model Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450       2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox       2011       Jeep
# 2  45774419   8467     -        HONDA      FIT       2006  Hatchback
# 3  45769185   3607   862         FORD   Escape       2011       Jeep
# 4  45809263  11726   446        HONDA      FIT       2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# ...

# %%
manufacturer_list=[]
for i in df_cleardup_ID:
    manufacturer_list=manufacturer_list.append(df_cleardup_ID.loc[i,3])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\anaconda\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 3
#       1 manufacturer_list=[]
#       2 for i in df_cleardup_ID:
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')


# make data
x = [1, 2, 3, 4]
colors = plt.get_cmap('Blues')(np.linspace(0.2, 0.7, len(x)))

# plot
fig, ax = plt.subplots()
ax.pie(x, colors=colors, radius=3, center=(4, 4),
       wedgeprops={"linewidth": 1, "edgecolor": "white"}, frame=True)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plt.style.use('_mpl-gallery')

# make data
#np.random.seed(1)
#x = 4 + np.random.normal(0, 1.5, 200)

# plot:

#imgsize
plt.figure(figsize=(100, 50))
plt.hist(df_cleardup_ID['Manufacturer'],bins=70, linewidth=3,rwidth=0.2, edgecolor="black")



plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np



# plot


ax.scatter(df_cleardup_ID['Manufacturer'], c=colors, vmin=0, vmax=100)



plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 9
#       2 import numpy as np
#       6 # plot
# ----> 9 ax.scatter(df_cleardup_ID['Manufacturer'], c=colors, vmin=0, vmax=100)
#      13 plt.show()
#
# File D:\anaconda\Lib\site-packages\matplotlib\__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# TypeError: Axes.scatter() missing 1 required positional argument: 'y'

# %%
import matplotlib.pyplot as plt
import numpy as np

#plt.style.use('_mpl-gallery')

# make data
#np.random.seed(1)
#x = 4 + np.random.normal(0, 1.5, 200)

# plot:

#imgsize
plt.figure(figsize=(10, 6))
plt.hist(df_cleardup_ID['Drive wheels'], linewidth=0.5, edgecolor="white")



plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


# plot:

plt.figure(figsize=(6, 6))
plt.hist(df_cleardup_ID['Leather interior'], bins=5, linewidth=2, edgecolor="black")



plt.show()

# %%
#df_cleardup_ID['Leather interior']
for i in df_cleardup_ID:
    list_leather=list_leather.append(df_cleardup_ID['Leather interior'])
print(list_leather)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[77], line 3
#       1 #df_cleardup_ID['Leather interior']
#       2 for i in df_cleardup_ID:
# ----> 3     list_leather=list_leather.append(df_cleardup_ID['Leather interior'])
#       4 print(list_leather)
#
# AttributeError: 'NoneType' object has no attribute 'append'

# %%
df_cleardup_ID.dtypes
# Out:
# ID                   object
# Price                 int64
# Levy                 object
# Manufacturer         object
# Model                object
# Prod. year           object
# Category             object
# Leather interior     object
# Fuel type            object
# Engine volume        object
# Mileage              object
# Cylinders           float64
# Gear box type        object
# Drive wheels         object
# Doors                object
# Wheel                object
# Color                object
# Airbags               int64
# dtype: object
