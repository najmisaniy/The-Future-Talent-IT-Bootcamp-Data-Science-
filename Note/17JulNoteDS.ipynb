# %%
import pandas as pd

# %%
import pandas as pd  
import numpy as np
from datetime import datetime, timedelta

#Create numerical ddataframe_columns

col1 = np.random.normal(250,10,500)
col2 = np.random.normal(300,20,500)
col3 = np.random.normal(750,5,500)

#Create categorical data 

categorical_data = ['A','B','C','D','E','F','G','H','I','J']

col4 = np.random.choice(categorical_data, 500)
col5 = np.random.choice(categorical_data, 500)

#Create date data 

start_date= datetime(2022,1,1)
end_date= datetime(2024,1,1)

delta = end_date-start_date
date_list = [start_date + timedelta(days=x) for x in range(delta.days)]

col6 = np.random.choice(date_list,500)


#Compile all the fiature

data = np.column_stack((col1, col2, col3, col4, col5, col6))

df = pd.DataFrame(data, columns = ['Num1','Num2','Num3','Cat1','Cat2','Cat3'])

df.head()
# Out:
#          Num1        Num2        Num3 Cat1 Cat2       Cat3
# 0  252.107294   341.01995  756.147339    E    D 2023-06-25
# 1  264.685143   252.35422  747.906041    F    D 2022-05-13
# 2  238.157236  304.919274  754.368636    I    J 2022-08-27
# 3  242.444839  339.979294  745.801012    G    D 2023-06-09
# 4  255.355903  334.088576  741.887768    G    I 2023-01-06

# %%
df.shape
# Out:
# (500, 6)

# %%
df.describe(include='all')
# Out:
#               Num1       Num2        Num3 Cat1 Cat2  \
# count   500.000000  500.00000  500.000000  500  500
# unique         NaN  500.00000  500.000000   10   10
# top            NaN  341.01995  756.147339    G    I
# freq           NaN    1.00000    1.000000   60   60
# mean    249.940687        NaN         NaN  NaN  NaN
# min     216.308093        NaN         NaN  NaN  NaN
# 25%     243.388713        NaN         NaN  NaN  NaN
# 50%     250.505660        NaN         NaN  NaN  NaN
# 75%     256.228240        NaN         NaN  NaN  NaN
# max     283.617182        NaN         NaN  NaN  NaN
# std      10.092201        NaN         NaN  NaN  NaN
#
#                               Cat3
# count                          500
# unique                         NaN
# top                            NaN
# freq                           NaN
# mean    2023-01-07 05:34:04.800000
# min            2022-01-02 00:00:00
# 25%            2022-07-23 06:00:00
# 50%            2023-01-18 12:00:00
# ...

# %%
df['Num1']=df['Num1'].astype('float')
df['Num2']=df['Num2'].astype('float')
df['Num3']=df['Num3'].astype('float')

df.dtypes
# Out:
# Num1           float64
# Num2           float64
# Num3           float64
# Cat1            object
# Cat2            object
# Cat3    datetime64[ns]
# dtype: object

# %%
df.describe()
# Out:
#              Num1        Num2        Num3                        Cat3
# count  500.000000  500.000000  500.000000                         500
# mean   249.940687  300.493510  749.951471  2023-01-07 05:34:04.800000
# min    216.308093  237.220017  736.985164         2022-01-02 00:00:00
# 25%    243.388713  288.764434  746.656313         2022-07-23 06:00:00
# 50%    250.505660  300.071834  749.858104         2023-01-18 12:00:00
# 75%    256.228240  312.982871  753.755635         2023-06-24 00:00:00
# max    283.617182  349.008863  762.721634         2023-12-30 00:00:00
# std     10.092201   19.413140    4.946401                         NaN

# %%
import pandas as pd  
import numpy as np

df_usedcar_data=pd.read_csv('train.csv')
df_usedcar_data.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# ...

# %%
df_usedcar_data.describe(include='all')
# Out:
#                   ID         Price   Levy Manufacturer  Model    Prod. year  \
# count   1.923700e+04  1.923700e+04  19237        19237  19237  19237.000000
# unique           NaN           NaN    559           65   1590           NaN
# top              NaN           NaN      -      HYUNDAI  Prius           NaN
# freq             NaN           NaN   5819         3769   1083           NaN
# mean    4.557654e+07  1.855593e+04    NaN          NaN    NaN   2010.912824
# std     9.365914e+05  1.905813e+05    NaN          NaN    NaN      5.668673
# min     2.074688e+07  1.000000e+00    NaN          NaN    NaN   1939.000000
# 25%     4.569837e+07  5.331000e+03    NaN          NaN    NaN   2009.000000
# 50%     4.577231e+07  1.317200e+04    NaN          NaN    NaN   2012.000000
# 75%     4.580204e+07  2.207500e+04    NaN          NaN    NaN   2015.000000
# max     4.581665e+07  2.630750e+07    NaN          NaN    NaN   2020.000000
#
# ...

# %%
df_usedcar_data['ID']=df_usedcar_data['ID'].astype('str')
df_usedcar_data['Prod. year']=df_usedcar_data['Prod. year'].astype('str')

df_usedcar_data.describe(include='all')
# Out:
#               ID         Price   Levy Manufacturer  Model Prod. year Category  \
# count      19237  1.923700e+04  19237        19237  19237      19237    19237
# unique     18924           NaN    559           65   1590         54       11
# top     45815365           NaN      -      HYUNDAI  Prius       2012    Sedan
# freq           8           NaN   5819         3769   1083       2155     8736
# mean         NaN  1.855593e+04    NaN          NaN    NaN        NaN      NaN
# std          NaN  1.905813e+05    NaN          NaN    NaN        NaN      NaN
# min          NaN  1.000000e+00    NaN          NaN    NaN        NaN      NaN
# 25%          NaN  5.331000e+03    NaN          NaN    NaN        NaN      NaN
# 50%          NaN  1.317200e+04    NaN          NaN    NaN        NaN      NaN
# 75%          NaN  2.207500e+04    NaN          NaN    NaN        NaN      NaN
# max          NaN  2.630750e+07    NaN          NaN    NaN        NaN      NaN
#
# ...

# %%
df_usedcar_data.dtypes
# Out:
# ID                   object
# Price                 int64
# Levy                 object
# Manufacturer         object
# Model                object
# Prod. year           object
# Category             object
# Leather interior     object
# Fuel type            object
# Engine volume        object
# Mileage              object
# Cylinders           float64
# Gear box type        object
# Drive wheels         object
# Doors                object
# Wheel                object
# Color                object
# Airbags               int64
# dtype: object

# %%
df_usedcar_data.describe()
# Out:
#               Price     Cylinders       Airbags
# count  1.923700e+04  19237.000000  19237.000000
# mean   1.855593e+04      4.582991      6.582627
# std    1.905813e+05      1.199933      4.320168
# min    1.000000e+00      1.000000      0.000000
# 25%    5.331000e+03      4.000000      4.000000
# 50%    1.317200e+04      4.000000      6.000000
# 75%    2.207500e+04      4.000000     12.000000
# max    2.630750e+07     16.000000     16.000000

# %%
df_cleardup_ID=df_usedcar_data.drop_duplicates(subset='ID')

# %%
df_usedcar_data.describe(include='all')
# Out:
#               ID         Price   Levy Manufacturer  Model Prod. year Category  \
# count      19237  1.923700e+04  19237        19237  19237      19237    19237
# unique     18924           NaN    559           65   1590         54       11
# top     45815365           NaN      -      HYUNDAI  Prius       2012    Sedan
# freq           8           NaN   5819         3769   1083       2155     8736
# mean         NaN  1.855593e+04    NaN          NaN    NaN        NaN      NaN
# std          NaN  1.905813e+05    NaN          NaN    NaN        NaN      NaN
# min          NaN  1.000000e+00    NaN          NaN    NaN        NaN      NaN
# 25%          NaN  5.331000e+03    NaN          NaN    NaN        NaN      NaN
# 50%          NaN  1.317200e+04    NaN          NaN    NaN        NaN      NaN
# 75%          NaN  2.207500e+04    NaN          NaN    NaN        NaN      NaN
# max          NaN  2.630750e+07    NaN          NaN    NaN        NaN      NaN
#
# ...

# %%
df_cleardup_ID.describe(include=('all'))
# Out:
#               ID         Price   Levy Manufacturer  Model Prod. year Category  \
# count      18924  1.892400e+04  18924        18924  18924      18924    18924
# unique     18924           NaN    559           65   1590         54       11
# top     45654403           NaN      -      HYUNDAI  Prius       2012    Sedan
# freq           1           NaN   5709         3729   1069       2131     8600
# mean         NaN  1.858744e+04    NaN          NaN    NaN        NaN      NaN
# std          NaN  1.921356e+05    NaN          NaN    NaN        NaN      NaN
# min          NaN  1.000000e+00    NaN          NaN    NaN        NaN      NaN
# 25%          NaN  5.331000e+03    NaN          NaN    NaN        NaN      NaN
# 50%          NaN  1.317200e+04    NaN          NaN    NaN        NaN      NaN
# 75%          NaN  2.206300e+04    NaN          NaN    NaN        NaN      NaN
# max          NaN  2.630750e+07    NaN          NaN    NaN        NaN      NaN
#
# ...

# %%
from matplotlib import pyplot as plt
x=[1,2,3,4,5,6,7,8,] 
y=[4,7,9,10,13,15,17,19]

plt.plot(x,y)
plt.show()

# %%
from matplotlib import pyplot as plt
x=[1,2,3,4,5,6,7,8,] 
y=[4,7,9,10,13,15,17,19]
plt.plot(x,y, color = 'y', linestyle='-', marker='x')
x1=[2,3,5,6,8,10,11]
y1=[3,5,8,11,14,16,18]
plt.plot(x1,y1, color = 'g', linestyle='--',marker='X')
x2=[0,1,2,3,4,5,6,7]
y2=[2,6,7,8,10,11,13,14]
plt.plot(x2,y2, color = 'r', linestyle='--',marker='X')

plt.xlabel('Numbers of year')
plt.ylabel('Car')
plt.title('Salary in KL')
plt.legend(['Company A','Company B','Compny C'])
plt.show()

# %%
x=[1,2,3,4,5,6,7,8,] 
y=[4,7,9,10,13,15,17,19]
plt.plot(x,y, color = 'y', linestyle='-', marker='x')
x1=[2,3,5,6,8,10,11]
y1=[3,5,8,11,14,16,18]
plt.plot(x1,y1, color = 'g', linestyle='--',marker='X')
x2=[0,1,2,3,4,5,6,7]
y2=[2,6,7,8,10,11,13,14]
plt.plot(x2,y2, color = 'r', linestyle='--',marker='X')

plt.xlabel('Numbers of year')
plt.ylabel('Car')
plt.title('Salary in KL')
plt.legend(['Company A','Company B','Compny C'])
plt.grid(True)
plt.show()

# %%
#generate random data 

data = np.random.random([5,5])
plt.imshow(data)

# %%
import geopandas as gpd

# Load a world map using GeoPandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Create a geographic heatmap
world.plot(column='gdp_md_est', cmap='OrRd', legend=True)
plt.title('Geographic Heatmap of GDP')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[249], line 1
# ----> 1 import geopandas as gpd
#       3 # Load a world map using GeoPandas
#       4 world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
#
# ModuleNotFoundError: No module named 'geopandas'
